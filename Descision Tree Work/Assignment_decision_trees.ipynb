# %% [markdown]
# # Decision Trees
#
# You will need to install graphviz and refer to the scikit learn documentation to complete this exercise.
#
# conda install python-graphviz
#
# http://scikit-learn.org/stable/modules/tree.html

# %% [markdown]
# ## Classification
#
# Use the Iris dataset for the classification exercise

# %%
from IPython import display
from sklearn import datasets, tree, utils
from sklearn.externals.six import StringIO  
import graphviz 
from sklearn.datasets import load_iris
from sklearn import tree

# data set has 3 classes, 50 observations each
iris = datasets.load_iris()
print (iris['DESCR'])
# Out:
# Iris Plants Database
# ...
#
# Notes
# -----
# Data Set Characteristics:
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20  0.76     0.9565  (high!)
# ...

# %% [markdown]
# ## Hyperparameters
#
# Hyperparameters can be used to control the architecture of decision trees.  See documentation for detailed description
#
# http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %%
# Train decision tree on the iris dataset
X_iris, y_iris = utils.shuffle(iris.data, iris.target, random_state=0) # shuffle firs￼￼￼￼￼￼t

# %%
# TO DO: train and plot the decision tree
# Set max_depth to 4

#leave the default values for everything but the max depth which is the third parameter
dectree = tree.DecisionTreeClassifier("gini", "best", 4, 2, 1, 0.0, None, None, None, 0.0, None, None, False)
dectree = dectree.fit(x_iris, y_iris)

#set depth to 4, plot the tree

dot_data = tree.export_graphviz(dectree, out_file=None, 
                         feature_names=iris.feature_names,  
                         class_names=iris.target_names,  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
# After training the model can be used to make predictions of the class labels

# TO DO: print the predicted labels of the following test data:

test_arr = [[4.8, 2.9, 1.5, 0.2],  #setosa
            [6.8, 2.6, 4.5, 1.4],  #versicolor
            [5.8, 3.7, 1.6, 2.3]]  #virginica

for i in dectree.predict(test_arr):
    if i==0:
        print("setosa")
    elif i==1:
        print("versicolor")
    else:
        print("virginica")
# Out:
# setosa
# versicolor
# versicolor

# %% [markdown]
# # Regression
#
# Use the Boston housing price dataset for this exercise

# %%
from sklearn import model_selection
import pandas as pd

boston = datasets.load_boston()
print (boston['DESCR'])
# Out:
# Boston House Prices dataset
# ...
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
# ...

# %%
# Shuffle first
X_boston, y_boston = utils.shuffle(boston.data, boston.target, random_state=42)

# TO DO: train and plot the decision tree
# Set max_depth to 3

dectree2 = tree.DecisionTreeRegressor('mse', 'best', 3, 2, 1, 0.0, None, None, None, 0.0, None, False)
dectree2 = dectree2.fit(X_boston, y_boston)

dot_data2 = tree.export_graphviz(dectree2, out_file=None)  
graph = graphviz.Source(dot_data2)  
graph
